# %% [markdown]
# <a href="https://colab.research.google.com/github/farhanajaved/Chainlink-for-SLA-Managment/blob/main/ICBC_graphs221123.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import plotly.graph_objects as go

import pandas as pd

df = pd.read_csv("https://raw.githubusercontent.com/farhanajaved/Chainlink_Oracle/main/Dataset2.csv")



#fig.update_traces(quartilemethod="exclusive") # or "inclusive", or "linear" by default

fig = px.violin(df, y="1_min")
fig1 = px.violin(df, y="2_min")
fig2 = px.violin(df, y="3_min")

fig.update_layout(
    xaxis_title='1 minute',
    yaxis_title='Amount LINK',
     template='simple_white',
     font=dict(
                #family="",
                size=12,
                color="black",
               
                
                 )
      ,width=330
    ,height=330)

fig1.update_layout(
    xaxis_title='2 minutes',
    yaxis_title='Amount LINK',
    template='simple_white',
    
     font=dict(
                #family="",
                size=12,
                color="black",
               
                
                 )
      ,width=330
    ,height=330)

fig2.update_layout(
    xaxis_title='3 minutes',
    yaxis_title='Amount LINK',
     template='simple_white',
     font=dict(
                #family="",
                size=12,
                color="black",
               
                
                 )
      ,width=330
    ,height=330)

fig.update_traces(box_visible=True, meanline_visible=True)

fig1.update_traces(box_visible=True, meanline_visible=True)

fig2.update_traces(box_visible=True, meanline_visible=True)


fig.show()
fig1.show()
fig2.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# 1, 2, 3 minutes

import plotly.graph_objects as go

import pandas as pd

import plotly.express as px


df = pd.read_csv("https://raw.githubusercontent.com/farhanajaved/Chainlink-for-SLA-Managment/main/Datasets/datset_18dec_updated.csv")



#fig.update_traces(quartilemethod="exclusive") # or "inclusive", or "linear" by default

fig = px.violin(df, y="1_min")
fig1 = px.violin(df, y="2_min")
fig2 = px.violin(df, y="3_min")

fig.update_layout(
    xaxis_title='1 minute',
    yaxis_title='Amount LINK',
    yaxis_exponentformat="none",
     template='simple_white',
     font=dict(
                #family="",
                size=12,
                color="black",
               
                
                 )
      ,width=330
    ,height=330)

fig1.update_layout(
    xaxis_title='2 minutes',
    yaxis_title='Amount LINK',
    template='simple_white',
    
     font=dict(
                #family="",
                size=12,
                color="black",
               
                
                 )
      ,width=330
    ,height=330)

fig2.update_layout(
    xaxis_title='3 minutes',
    yaxis_title='Amount LINK',
     template='simple_white',
     
     font=dict(
                #family="",
                size=12,
                color="black",
               
                
                 )
      ,width=330
    ,height=330)

fig.update_traces(box_visible=True, meanline_visible=True, fillcolor='lightseagreen', line_color='black')

fig1.update_traces(box_visible=True, meanline_visible=True, fillcolor='lightseagreen', line_color='black')

fig2.update_traces(box_visible=True, meanline_visible=True, fillcolor='lightseagreen', line_color='black')


fig.show()
fig1.show()
fig2.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# 5, 10, 15 minutes

import plotly.graph_objects as go

import pandas as pd

import plotly.express as px


df = pd.read_csv("https://raw.githubusercontent.com/farhanajaved/Chainlink-for-SLA-Managment/main/Datasets/dataset2_51015.csv")



#fig.update_traces(quartilemethod="exclusive") # or "inclusive", or "linear" by default

fig = px.violin(df, y=" 5_min")
fig1 = px.violin(df, y="10_min")
fig2 = px.violin(df, y="15_min")

fig.update_layout(
    xaxis_title='5 minute',
    yaxis_title='Amount LINK',
    yaxis_exponentformat="none",
     template='simple_white',
     font=dict(
                #family="",
                size=12,
                color="black",
               
                
                 )
      ,width=330
    ,height=330)

fig1.update_layout(
    xaxis_title='10 minutes',
    yaxis_title='Amount LINK',
    template='simple_white',
    
     font=dict(
                #family="",
                size=12,
                color="black",
               
                
                 )
      ,width=330
    ,height=330)

fig2.update_layout(
    xaxis_title='15 minutes',
    yaxis_title='Amount LINK',
     template='simple_white',
     
     font=dict(
                #family="",
                size=12,
                color="black",
               
                
                 )
      ,width=330
    ,height=330)

fig.update_traces(box_visible=True, meanline_visible=True, fillcolor='lightseagreen', line_color='black')

fig1.update_traces(box_visible=True, meanline_visible=True, fillcolor='lightseagreen', line_color='black')

fig2.update_traces(box_visible=True, meanline_visible=True, fillcolor='lightseagreen', line_color='black')


fig.show()
fig1.show()
fig2.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#TxnCost_5k_17Nov

import plotly.graph_objects as go

import pandas as pd

import plotly.express as px

df = pd.read_csv("https://raw.githubusercontent.com/farhanajaved/Chainlink-for-SLA-Managment/main/Datasets/TxnCost_5k_17Nov.csv")



#fig.update_traces(quartilemethod="exclusive") # or "inclusive", or "linear" by default

fig = px.violin(df, y="TxnFee(MATIC)")
fig1 = px.violin(df, y="TxnFee(USD)")
#fig2 = px.violin(df, y="15_min")

fig.update_layout(
    xaxis_title='5000 Txn (Day 1)' ,
    yaxis_title='TxnFee(MATIC)',
    yaxis_exponentformat="none",
     template='simple_white',
     font=dict(
                #family="",
                size=12,
                color="black",
               
                
                 )
      ,width=330
    ,height=330)

fig1.update_layout(
    xaxis_title='5000 Txn (Day 1)',
    yaxis_title='TxnFee(USD)',
    template='simple_white',
    
     font=dict(
                #family="",
                size=12,
                color="black",
               
                
                 )
      ,width=330
    ,height=330)


fig.update_traces(box_visible=True, meanline_visible=True, fillcolor='lightseagreen', line_color='black')

fig1.update_traces(box_visible=True, meanline_visible=True, fillcolor='lightseagreen', line_color='black')

#fig2.update_traces(box_visible=True, meanline_visible=True, fillcolor='lightseagreen', line_color='black')


fig.show()
fig1.show()
#fig2.show()
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-2-83a8c067c623> in <module>
#       7 import plotly.express as px
#       8
# ----> 9 df = pd.read_csv("https://raw.githubusercontent.com/farhanajaved/Chainlink_Oracle/main/TxnCost_5k_17Nov.csv")
#      10
#      11
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
#TxnCost_5K_18Nov

import plotly.graph_objects as go

import pandas as pd

import plotly.express as px

df = pd.read_csv("https://raw.githubusercontent.com/farhanajaved/Chainlink-for-SLA-Managment/main/Datasets/TxnCost_5K_18Nov.csv")



#fig.update_traces(quartilemethod="exclusive") # or "inclusive", or "linear" by default

fig = px.violin(df, y="TxnFee(MATIC)")
fig1 = px.violin(df, y="TxnFee(USD)")
#fig2 = px.violin(df, y="15_min")

fig.update_layout(
    xaxis_title='5000 Txn (Day 2)' ,
    yaxis_title='TxnFee(MATIC)',
    yaxis_exponentformat="none",
     template='simple_white',
     font=dict(
                #family="",
                size=12,
                color="black",
               
                
                 )
      ,width=330
    ,height=330)

fig1.update_layout(
    xaxis_title='5000 Txn (Day 2)',
    yaxis_title='TxnFee(USD)',
    template='simple_white',
    
     font=dict(
                #family="",
                size=12,
                color="black",
               
                
                 )
      ,width=330
    ,height=330)


fig.update_traces(box_visible=True, meanline_visible=True, fillcolor='lightseagreen', line_color='black')

fig1.update_traces(box_visible=True, meanline_visible=True, fillcolor='lightseagreen', line_color='black')

#fig2.update_traces(box_visible=True, meanline_visible=True, fillcolor='lightseagreen', line_color='black')


fig.show()
fig1.show()
#fig2.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#TxnCost_5k_19Nov


import plotly.graph_objects as go

import pandas as pd

import plotly.express as px

df = pd.read_csv("https://raw.githubusercontent.com/farhanajaved/Chainlink-for-SLA-Managment/main/Datasets/TxnCost_5k_19Nov.csv")



#fig.update_traces(quartilemethod="exclusive") # or "inclusive", or "linear" by default

fig = px.violin(df, y="TxnFee(MATIC)")
fig1 = px.violin(df, y="TxnFee(USD)")
#fig2 = px.violin(df, y="15_min")

fig.update_layout(
    xaxis_title='5000 Txn (Day 3)' ,
    yaxis_title='TxnFee(MATIC)',
    yaxis_exponentformat="none",
     template='simple_white',
     font=dict(
                #family="",
                size=12,
                color="black",
               
                
                 )
      ,width=330
    ,height=330)

fig1.update_layout(
    xaxis_title='5000 Txn (Day 3)',
    yaxis_title='TxnFee(USD)',
    template='simple_white',
    
     font=dict(
                #family="",
                size=12,
                color="black",
               
                
                 )
      ,width=330
    ,height=330)


fig.update_traces(box_visible=True, meanline_visible=True, fillcolor='lightseagreen', line_color='black')

fig1.update_traces(box_visible=True, meanline_visible=True, fillcolor='lightseagreen', line_color='black')

#fig2.update_traces(box_visible=True, meanline_visible=True, fillcolor='lightseagreen', line_color='black')


fig.show()
fig1.show()
#fig2.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import plotly.graph_objects as go

import pandas as pd

import plotly.express as px


long_df = pd.read_csv("https://raw.githubusercontent.com/farhanajaved/Chainlink-for-SLA-Managment/main/Datasets/Size.csv")

print(df.head())


fig = px.bar(long_df, x = 'Metrices', y = 'Size ', text_auto=True)

#fig = px.bar(long_df, x, y, text_auto=True)

fig.update_layout(
    xaxis_title='Metrices' ,
    yaxis_title='Size (KB)',
   # yaxis_exponentformat="none",
     template='simple_white',
     font=dict(
                #family="",
                size=12,
                color="black",
               
                
                 )
      ,width=830
    ,height=530)
fig.update_layout(uniformtext_minsize=8, uniformtext_mode='hide')



fig.show()
# Out:
#                         Metrices   Size
# 0         Core_MANO_Wrapper_Time  12.500
# 1             Create_AIML_alerts   5.310
# 2         Create_Monitoring_Jobs   3.360
# 3          Create_Threshold_Jobs   0.514
# 4  Hierarchical_SOE_Dispatching    1.130
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# https://raw.githubusercontent.com/farhanajaved/Chainlink-for-SLA-Managment/main/Datasets/SizeandKPIs.csv
# Size and KPIs selected from each

import plotly.graph_objects as go

import pandas as pd

import plotly.express as px


long_df = pd.read_csv("https://raw.githubusercontent.com/farhanajaved/Chainlink-for-SLA-Managment/main/Datasets/SizeandKPIs.csv")

#print(df.head())


fig = px.bar(long_df, y = 'Size', text_auto=True, color="Metrices")

#fig = px.bar(long_df, x, y, text_auto=True)

fig.update_layout(
    xaxis_title='No. of raw logs' ,
    yaxis_title='Size (KB)',
   # yaxis_exponentformat="none",
     template='simple_white',
     font=dict(
                #family="",
                size=12,
                color="black",
               
                
                 )
      ,width=630
    ,height=450)
fig.update_layout(uniformtext_minsize=8, uniformtext_mode='hide')



fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# https://raw.githubusercontent.com/farhanajaved/Chainlink-for-SLA-Managment/main/Datasets/Cleanlogs.csv

# Clean logs

import plotly.graph_objects as go

import pandas as pd

import plotly.express as px


long_df = pd.read_csv("https://raw.githubusercontent.com/farhanajaved/Chainlink-for-SLA-Managment/main/Datasets/CleanlogsUC.csv")

print(long_df.head())


fig = px.bar(long_df, x = 'Data_logs', y = 'Size', text_auto=True, color="Logging_Innovalia")

#fig = px.bar(long_df, x, y, text_auto=True)

fig.update_layout(
    xaxis_title='Clean Logs' ,
    yaxis_title='Size (MB)',
   # yaxis_exponentformat="none",
     template='simple_white',
     font=dict(
                #family="",
                size=12,
                color="black",
               
                
                 )
      ,width=430
    ,height=330)
fig.update_layout(uniformtext_minsize=8, uniformtext_mode='hide')



fig.show()
# Out:
#   Logging_Innovalia Data_logs   Size
# 0         Use-Case1     5grso  0.358
# 1         Use-Case1        Vs  1.200
# 2         Use-Case2     5grso  0.332
# 3         Use-Case2        Vs  1.160
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# https://raw.githubusercontent.com/farhanajaved/Chainlink-for-SLA-Managment/main/Datasets/setIPFShash.csv

# SetIPFSHash function


import plotly.graph_objects as go

import pandas as pd

import plotly.express as px

df = pd.read_csv("https://raw.githubusercontent.com/farhanajaved/Chainlink-for-SLA-Managment/main/Datasets/setIPFShash3.csv")



#fig.update_traces(quartilemethod="exclusive") # or "inclusive", or "linear" by default

fig = px.violin(df, y="TxnFee(MATIC)")
fig1 = px.violin(df, y="TxnFee(USD)")
#fig2 = px.violin(df, y="15_min")

fig.update_layout(
    xaxis_title='SetIPFS' ,
    yaxis_title='TxnFee(MATIC)',
    yaxis_exponentformat="none",
     template='simple_white',
     font=dict(
                #family="",
                size=12,
                color="black",
               
                
                 )
      ,width=330
    ,height=330)

fig1.update_layout(
    xaxis_title='SetIPFS',
    yaxis_title='TxnFee(USD)',
    template='simple_white',
    
     font=dict(
                #family="",
                size=12,
                color="black",
               
                
                 )
      ,width=330
    ,height=330)


fig.update_traces(box_visible=True, meanline_visible=True, fillcolor='lightseagreen', line_color='black')

fig1.update_traces(box_visible=True, meanline_visible=True, fillcolor='lightseagreen', line_color='black')

#fig2.update_traces(box_visible=True, meanline_visible=True, fillcolor='lightseagreen', line_color='black')


fig.show()
fig1.show()
#fig2.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
